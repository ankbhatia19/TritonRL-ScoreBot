# %%
import pandas as pd
from player_data_processing import *

# %%
stats = pd.read_csv("TRL-stats-3.csv", header=0, sep = ";")

# %%
stats = get_totals(stats)
# Out:
# C:\Users\Q's\Python Stuff\Triton-Replay-Bot\TritonRL-ScoreBot\src\player_statistics\player_data_processing.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['player name'] = total["player name"].str.lower()

# %%
stats.columns
# Out:
# Index(['player name', 'games', 'wins', 'score', 'goals', 'assists', 'saves',
#        'shots', 'shots conceded', 'goals conceded',
#        'goals conceded while last defender', 'amount collected',
#        'amount collected big pads', 'amount collected small pads',
#        'count collected big pads', 'count collected small pads',
#        'amount stolen', 'amount stolen big pads', 'amount stolen small pads',
#        'count stolen big pads', 'count stolen small pads', '0 boost time',
#        '100 boost time', 'amount used while supersonic',
#        'amount overfill total', 'amount overfill stolen', 'total distance',
#        'time slow speed', 'time boost speed', 'time supersonic speed',
#        'time on ground', 'time low in air', 'time high in air',
#        'time powerslide', 'count powerslide', 'time most back',
#        'time most forward', 'time in front of ball', 'time behind ball',
#        'time defensive half', 'time offensive half', 'time defensive third',
# ...

# %%
stats
# Out:
#                    player name  games  wins  score  goals  assists  saves  \
# 0                    beluga rl     31    13  12731     23       15     62
# 1                   bobabooyah     55    32  21206     54       31     79
# 2                          boi     49    24  22518     66       22     73
# 3                     brictone      1     1    336      1        0      1
# 4        caden the fish fisher     49    24  17223     32       28     69
# 5                   dazedrex69     31    13   6883     12       12     31
# 6                   desolation      5     2   1297      2        1      4
# 7                       dreamz     46    25  16889     31       24     74
# 8               graham cracker      4     1   1028      0        2      4
# 9                      honesty     25    16   8936     23       11     28
# 10                     hotshot     33    12  12478     24       19     40
# 11             ix commanderboy     43    23  16408     35       29     54
# ...

# %%
same_player_dict = {"ix commanderboy (slumping)" : 'ix commanderboy',
                   'slumpanderboy' : 'ix commanderboy',
                   'desolation' : 'honesty',
                   'powerracerx 45' : 'ix solo',
                   'jfox' : 'jbassfox',
                   'brictone' : 'hotshot',
                   'kzesty' : 'waycey'}

# %%
stats = patch_duplicates(stats, same_player_dict)

# %%
stats = average_player_statistics(stats)

# %%
stats
# Out:
#               player name  games    wins     score   goals  assists   saves  \
# 0               beluga rl     31  0.4194  410.6774  0.7419   0.4839  2.0000
# 1              bobabooyah     55  0.5818  385.5636  0.9818   0.5636  1.4364
# 2                     boi     49  0.4898  459.5510  1.3469   0.4490  1.4898
# 3   caden the fish fisher     49  0.4898  351.4898  0.6531   0.5714  1.4082
# 4              dazedrex69     31  0.4194  222.0323  0.3871   0.3871  1.0000
# 5                  dreamz     46  0.5435  367.1522  0.6739   0.5217  1.6087
# 6          graham cracker      4  0.2500  257.0000  0.0000   0.5000  1.0000
# 7                 ix mini     46  0.5435  541.4783  1.2609   0.3478  2.0870
# 8          kenthesilencer     37  0.6216  285.7027  0.6486   0.3784  0.8649
# 9                   kyles     33  0.3333  382.1212  0.6667   0.3333  1.6364
# 10                   luke     55  0.5818  273.2727  0.7455   0.3455  0.9273
# ...

# %%
offense = offensive_stats(stats)
defense = defensive_stats(stats)
agg_stats = aggression_stats(stats)
speed = speed_stats(stats)
stats_all = generate_overall_standings(stats, offense, defense, agg_stats, speed)
# Out:
# C:\Users\Q's\Python Stuff\Triton-Replay-Bot\TritonRL-ScoreBot\src\player_statistics\player_data_processing.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Offensive['Offensive Rating'] = .05*Offensive['score'] + .2*Offensive['shots'] \
# C:\Users\Q's\Python Stuff\Triton-Replay-Bot\TritonRL-ScoreBot\src\player_statistics\player_data_processing.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Offensive['Offensive Rating']  = scaler.fit_transform(Offensive[['Offensive Rating']])
# ...

# %%
stats_all
# Out:
#               participant  win rate  Overall  Offense  Defense  Aggression  \
# 0              nsdlakers4      0.62   100.00    74.72    71.28       96.18
# 1                  reuben      0.60    98.69   100.00   100.00       66.89
# 2                 ix mini      0.54    97.01    80.43    62.44      100.00
# 3                     boi      0.49    82.37    68.70    57.35       91.17
# 4                 ix solo      0.40    67.64    70.83    55.79       60.39
# 5                   kyles      0.33    65.94    55.50    64.77       67.25
# 6                 hotshot      0.38    64.93    61.57    41.85       70.70
# 7         ix commanderboy      0.53    62.83    52.20    39.76       80.23
# 8              terminator      0.58    58.04    54.65    36.20       72.12
# 9               beluga rl      0.42    57.51    49.97    51.40       63.07
# 10                 dreamz      0.54    57.07    45.08    61.03       53.46
# ...

# %%
stats_all.to_csv("overalls.csv")
